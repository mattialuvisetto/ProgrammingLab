# %% [markdown]
# # Nozioni di base su Markdown
#
# Markdown è un linguaggio simile a lateX

# %% [markdown]
# Viene eseguita solo l'ultima riga della cella, il modo per eseguire più roba è salvare in tuple
#
# Si può interagire direttamente dal terminale

# %%
print("Hello, World!")
# Out:
# Hello, World!

# %% [markdown]
# ## PEP 8

# %% [markdown]
# Lo slicing non da mai errore anche se considero degli indici che non ci sono nella lista
#
# le funzioni LAMBDA sono scritte su una sola riga
