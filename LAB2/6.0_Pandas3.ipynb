# %% [markdown]
# ## Esamina i Dati
#
# Carichiamo i dati usando `read_csv` e diamo un'occhiata rapida con `head()`.

# %%
# Importing Libraries
import pandas as pd
import numpy as np
from datasets import load_dataset
import matplotlib.pyplot as plt  



# Carica il dataset
dataset = load_dataset("yiqing111/Engineering_Jobs_Insight_Dataset")
# Converte in DataFrame Pandas
df = dataset['train'].to_pandas()
# Rimpiazza gli spazi con l'underscore
df.columns = df.columns.str.replace(' ', '_')
# Convertire 'Date_Posted' in datetime senza specificare il formato esatto
df['Date_Posted'] = pd.to_datetime(df['Date_Posted'], errors='coerce')
# Out:
# Repo card metadata block was not found. Setting CardData to empty.

# %%
df.head()
# Out:
#                            Job_Title                     Company  \
# 0  Senior Software Engineer (Python)                   BP Energy
# 1      Sr. Backend Software Engineer                      Meijer
# 2     Sr. Software Engineer - Mobile                      Meijer
# 3      Acquisition Software Engineer  Naval Air Systems Command
# 4           Senior Software Engineer                      Innova
#
#                                          Description                 Location  \
# 0  Entity: Trading & Shipping Job Family Group: S...       Crestwood, Houston
# 1  As a family company, we serve people and commu...     Belmont, Kent County
# 2  As a family company, we serve people and commu...     Belmont, Kent County
# 3  Position Description The Harpoon/SLAM ER/JSOW ...  China Lake, Kern County
# 4  A client of Innova Solutions is immediately hi...       Richardson, Dallas
#
#    Salary_Min  Salary_Max               Date_Posted  \
# 0   138992.40   138992.40 2024-10-29 16:35:26+00:00
# 1   118638.80   118638.80 2024-11-10 01:13:11+00:00
# 2   108041.95   108041.95 2024-10-15 11:51:30+00:00
# 3    88583.57    88583.57 2024-11-16 04:21:41+00:00
# 4   121932.35   121932.35 2024-11-15 09:42:55+00:00
#
#                                                  URL
# 0  https://www.adzuna.com/land/ad/4917931721?se=N...
# 1  https://www.adzuna.com/land/ad/4933370156?se=N...
# 2  https://www.adzuna.com/land/ad/4902683574?se=N...
# 3  https://www.adzuna.com/land/ad/4941260438?se=N...
# 4  https://www.adzuna.com/details/4940271538?utm_...

# %% [markdown]
# ## iloc
#
# Abbiamo già imparato come ottenere le righe usando `iloc[]`.
# Ma possiamo fare molto di più con questo strumento: possiamo infatti selezionare *sia* righe *che* colonne.
#
# Per fare questo, dobbiamo conoscere gli indici del nostro DataFrame.

# %%
df.iloc[0] #prima riga
# Out:
# Job_Title                      Senior Software Engineer (Python)
# Company                                                BP Energy
# Description    Entity: Trading & Shipping Job Family Group: S...
# Location                                      Crestwood, Houston
# Salary_Min                                              138992.4
# Salary_Max                                              138992.4
# Date_Posted                            2024-10-29 16:35:26+00:00
# URL            https://www.adzuna.com/land/ad/4917931721?se=N...
# Name: 0, dtype: object

# %% [markdown]
# ##### Nota: usa `df.iloc[0, 15]` invece di `df.iloc[0][15]` per garantire la compatibilità futura con pandas.
#
# L’uso dell’indicizzazione concatenata come `df.iloc[0][15]` è in fase di deprecazione in pandas, perché può portare a comportamenti ambigui tra accesso basato sulla posizione e accesso basato sull’etichetta nelle versioni future.
# Utilizzando `df.iloc[0, 15]`, specifichi direttamente la posizione dell’elemento che vuoi accedere, in modo più chiaro e sicuro, evitando potenziali errori futuri legati all’interpretazione degli indici interi nelle serie.
#
# Quindi dovremmo scrivere:

# %%
df.iloc[0,5]
# Out:
# np.float64(138992.4)

# %%
df.iloc[2:4,4:6]
# Out:
#    Salary_Min  Salary_Max
# 2   108041.95   108041.95
# 3    88583.57    88583.57

# %%
df.iloc[[2,4],[2,5]]
# Out:
#                                          Description  Salary_Max
# 2  As a family company, we serve people and commu...   108041.95
# 4  A client of Innova Solutions is immediately hi...   121932.35

# %% [markdown]
# ## loc
#
# * `df.loc[]`: seleziona righe e colonne per **etichetta** o **intervallo di etichette**.
# * È simile a `df.iloc[]`, ma consente di usare **etichette** invece degli indici numerici.

# %%
df.loc[:9,['Salary_Min',	'Salary_Max']]
# Out:
#    Salary_Min  Salary_Max
# 0   138992.40   138992.40
# 1   118638.80   118638.80
# 2   108041.95   108041.95
# 3    88583.57    88583.57
# 4   121932.35   121932.35
# 5   133348.23   133348.23
# 6    88769.20    88769.20
# 7    79830.78    79830.78
# 8    94173.15    94173.15
# 9    91324.85    91324.85

# %% [markdown]
# ## Gestione dei Dati Mancanti

# %% [markdown]
# - `df.dropna()`: elimina i valori mancanti.

# %% [markdown]
# ### Fillna
#
# - `df.fillna()`: riempie i valori mancanti

# %%
data = {
    'Nome': ['Anna', 'Luca', 'Marco', 'Elisa'],
    'Età': [25, np.nan, 30, np.nan],
    'Città': ['Roma', 'Milano', np.nan, 'Torino']
}

df2 = pd.DataFrame(data)
df2
# Out:
#     Nome   Età   Città
# 0   Anna  25.0    Roma
# 1   Luca   NaN  Milano
# 2  Marco  30.0     NaN
# 3  Elisa   NaN  Torino

# %%
df_drop = df2.dropna()
df_drop
# Out:
#    Nome   Età Città
# 0  Anna  25.0  Roma

# %%
media_eta = df2['Età'].mean()
df2['Età'] = df2['Età'].fillna(media_eta)
df2
# Out:
#     Nome   Età   Città
# 0   Anna  25.0    Roma
# 1   Luca  27.5  Milano
# 2  Marco  30.0     NaN
# 3  Elisa  27.5  Torino

# %% [markdown]
# ## Rimozione dei Duplicati
#
# * `drop_duplicates()`: rimuove le righe duplicate.
# * Gli analisti devono spesso ripulire i dati, e uno dei problemi più comuni che si incontrano sono i valori duplicati.

# %%
#Esempio
df = pd.DataFrame({
    'nome': ['Anna', 'Luca', 'Anna'],
    'eta': [20, 25, 20]
})

print(df)

# Rimozione duplicati
df_pulito = df.drop_duplicates()


print(df_pulito)
# Out:
#    nome  eta
# 0  Anna   20
# 1  Luca   25
# 2  Anna   20
#    nome  eta
# 0  Anna   20
# 1  Luca   25

# %% [markdown]
# Fate attezione a come copiate il dataframe

# %%
# DataFrame Copy
df_original = df.copy()
df_altered = df_original

# Filling the missing values with the median salary
df_altered['Salary_Min'] = 5
df_altered['Salary_Min']
# Out:
# 0    5
# 1    5
# 2    5
# Name: Salary_Min, dtype: int64

# %%
df_original['Salary_Min']
# Out:
# 0    5
# 1    5
# 2    5
# Name: Salary_Min, dtype: int64

# %%
df['Salary_Min']
# Out:
# 0        138992.40
# 1        118638.80
# 2        108041.95
# 3         88583.57
# 4        121932.35
#            ...
# 11180    110000.00
# 11181    110000.00
# 11182    126635.63
# 11183    155731.52
# 11184    174527.50
# Name: Salary_Min, Length: 11185, dtype: float64

# %%
print('ID of df_original:               ', id(df_original))
print('ID of df_altered:                ', id(df_altered))
print('ID of df:                        ', id(df))
# Out:
# ID of df_original:                14231462896
# ID of df_altered:                 14231462896
# ID of df:                         14192258432

# %% [markdown]
# ## Campionamento
#
# * `sample()`: estrae un campione casuale di elementi.
#
# ### Esempi
#
# Otteniamo un campione casuale dei dati.
# È possibile ottenere un campione con un numero fisso di righe.

# %%
df.sample(n=2)
# Out:
#                         Job_Title                           Company  \
# 6208  Business Systems Analyst II   CF Industries Employee Services
# 6064   Business Solutions Analyst  First International Bank & Trust
#
#                                             Description  \
# 6208  At CF Industries, our mission is to provide cl...
# 6064  First International Bank and Trust is a family...
#
#                            Location  Salary_Min  Salary_Max  \
# 6208        Northbrook, Cook County   101286.58   101286.58
# 6064  Sioux Falls, Minnehaha County    92668.23    92668.23
#
#                    Date_Posted  \
# 6208 2024-11-16 06:11:36+00:00
# 6064 2024-10-30 14:16:32+00:00
#
#                                                     URL
# 6208  https://www.adzuna.com/details/4941320291?utm_...
# 6064  https://www.adzuna.com/details/4918855817?utm_...

# %% [markdown]
# Oppure puoi selezionare casualmente una frazione dei dati (ad esempio, il 10% delle righe), con o senza reinserimento (replacement).

# %%
df.sample(frac=0.0005, replace=False) # (senza replacement) → ogni riga può essere selezionata una sola volta nel campione.
# Out:
#                                                Job_Title  \
# 327     Advanced Software Engineer - Industrial Software
# 10625                         Solutions Architect - SLED
# 7807                                      Cloud Engineer
# 8354   Senior Site Reliability Engineer, Omniverse Cl...
# 8200                      Sr. Cloud and Storage Engineer
# 10686                                Solutions Architect
#
#                             Company  \
# 327                        Symbotic
# 10625                       Verizon
# 7807   Applied Information Sciences
# 8354                     Nvidia Usa
# 8200    Contact Government Services
# 10686                      QSC, LLC
#
#                                              Description  \
# 327    Who we are With its A.I.-powered robotic techn...
# 10625  When you join Verizon You want more out of a c...
# 7807   If you’re seeking a sense of community and the...
# 8354   NVIDIA Omniverse Cloud is a platform of APIs, ...
# 8200   Sr. Cloud and Storage Engineer Employment Type...
# 10686  The Solutions Architect is responsible for pro...
#
#                                       Location  Salary_Min  Salary_Max  \
# 327              Prides Crossing, Essex County   117104.30   117104.30
# 10625  Annapolis Junction, Anne Arundel County   167525.62   167525.62
# 7807                              Virginia, US   116852.84   116852.84
# 8354            Santa Clara County, California        0.00   339250.00
# 8200                    Knoxville, Knox County   129792.00   187477.00
# 10686                      Remote, Coos County   107006.68   107006.68
#
#                     Date_Posted  \
# 327   2024-11-23 14:05:04+00:00
# 10625 2024-09-28 21:37:05+00:00
# 7807  2024-10-22 06:38:45+00:00
# 8354  2024-11-21 07:39:50+00:00
# 8200  2024-10-05 06:44:14+00:00
# 10686 2024-10-16 11:44:33+00:00
#
#                                                      URL
# 327    https://www.adzuna.com/land/ad/4949180628?se=5...
# 10625  https://www.adzuna.com/land/ad/4880844191?se=p...
# 7807   https://www.adzuna.com/details/4910075215?utm_...
# 8354   https://www.adzuna.com/details/4946613104?utm_...
# 8200   https://www.adzuna.com/details/4889930512?utm_...
# 10686  https://www.adzuna.com/details/4904139455?utm_...

# %% [markdown]
# ## Pandas Pivot
#
# È un'operazione che consente di ristrutturare un DataFrame, trasformando colonne in indici e viceversa. È utile quando vuoi riorganizzare i dati in una forma tabellare più leggibile o più adatta all’analisi.

# %%
df = pd.DataFrame({
    'Data': ['2024-01', '2024-01', '2024-02', '2024-02'],
    'Prodotto': ['A', 'B', 'A', 'B'],
    'Vendite': [100, 150, 120, 130]
})
df
# Out:
#       Data Prodotto  Vendite
# 0  2024-01        A      100
# 1  2024-01        B      150
# 2  2024-02        A      120
# 3  2024-02        B      130

# %%
# rioganizziamo i dati di modo che Le righe (index) siano le date, Le colonne, i prodotti, e le celle contengono i valori di vendite.

df.pivot(index='Data', columns='Prodotto', values='Vendite')
# Out:
# Prodotto    A    B
# Data
# 2024-01   100  150
# 2024-02   120  130

# %% [markdown]
# - `pivot_table()` è una versione più flessibile di `pivot()`, perché ti permette di aggregare dati quando ci sono valori duplicati per la combinazione di indice e colonne.
# * Syntax: `pivot_table(values='column_to_aggregate', index='row_index', columns='column_index', aggfunc='mean')`

# %%
df = pd.DataFrame({
    'Data': ['2024-01', '2024-01', '2024-01', '2024-02'],
    'Prodotto': ['A', 'A', 'B', 'B'],
    'Vendite': [100, 120, 150, 130]
})
df
# Out:
#       Data Prodotto  Vendite
# 0  2024-01        A      100
# 1  2024-01        A      120
# 2  2024-01        B      150
# 3  2024-02        B      130

# %%
df.pivot(index='Data', columns='Prodotto', values='Vendite')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 df.pivot(index='Data', columns='Prodotto', values='Vendite')
#
# File /opt/miniconda3/envs/labprog/lib/python3.12/site-packages/pandas/core/frame.py:10974, in DataFrame.pivot(self, columns, index, values)
#   10967 @Substitution("")
#   10968 @Appender(_shared_docs["pivot"])
#   10969 def pivot(
#   10970     self, *, columns, index=lib.no_default, values=lib.no_default
#   10971 ) -> DataFrame:
#   10972     from pandas.core.reshape.pivot import pivot
# > 10974     return pivot(self, index=index, columns=columns, values=values)
#
# File /opt/miniconda3/envs/labprog/lib/python3.12/site-packages/pandas/core/reshape/pivot.py:910, in pivot(data, columns, index, values)
#     905         indexed = data._constructor_sliced(data[values]._values, index=multiindex)
#     906 # error: Argument 1 to "unstack" of "DataFrame" has incompatible type "Union
#     907 # [List[Any], ExtensionArray, ndarray[Any, Any], Index, Series]"; expected
#     908 # "Hashable"
#     909 # unstack with a MultiIndex returns a DataFrame
# --> 910 result = cast("DataFrame", indexed.unstack(columns_listlike))  # type: ignore[arg-type]
#     911 result.index.names = [
#     912     name if name is not lib.no_default else None for name in result.index.names
#     913 ]
#     915 return result
#
# File /opt/miniconda3/envs/labprog/lib/python3.12/site-packages/pandas/core/series.py:4501, in Series.unstack(self, level, fill_value, sort)
#    4451 """
#    4452 Unstack, also known as pivot, Series with MultiIndex to produce DataFrame.
#    4453
#    (...)   4497 b    2    4
#    4498 """
#    4499 from pandas.core.reshape.reshape import unstack
# -> 4501 return unstack(self, level, fill_value, sort)
#
# File /opt/miniconda3/envs/labprog/lib/python3.12/site-packages/pandas/core/reshape/reshape.py:596, in unstack(obj, level, fill_value, sort)
#     594 if is_1d_only_ea_dtype(obj.dtype):
#     595     return _unstack_extension_series(obj, level, fill_value, sort=sort)
# --> 596 unstacker = _Unstacker(
#     597     obj.index, level=level, constructor=obj._constructor_expanddim, sort=sort
#     598 )
#     599 return unstacker.get_result(obj, value_columns=None, fill_value=fill_value)
#
# File /opt/miniconda3/envs/labprog/lib/python3.12/site-packages/pandas/core/reshape/reshape.py:176, in _Unstacker.__init__(self, index, level, constructor, sort)
#     168     if num_cells > np.iinfo(np.int32).max:
#     169         warnings.warn(
#     170             f"The following operation may generate {num_cells} cells "
#     171             f"in the resulting pandas object.",
#     172             PerformanceWarning,
#     173             stacklevel=find_stack_level(),
#     174         )
# --> 176 self._make_selectors()
#
# File /opt/miniconda3/envs/labprog/lib/python3.12/site-packages/pandas/core/reshape/reshape.py:232, in _Unstacker._make_selectors(self)
#     229 mask.put(selector, True)
#     231 if mask.sum() < len(self.index):
# --> 232     raise ValueError("Index contains duplicate entries, cannot reshape")
#     234 self.group_index = comp_index
#     235 self.mask = mask
#
# ValueError: Index contains duplicate entries, cannot reshape

# %%
df.pivot_table(index='Data', columns='Prodotto', values='Vendite', aggfunc='sum')
# Out:
# Prodotto      A      B
# Data
# 2024-01   220.0  150.0
# 2024-02     NaN  130.0

# %%
df.pivot_table(index='Prodotto', values='Vendite', aggfunc='sum')
# Out:
#           Vendite
# Prodotto
# A             220
# B             280

# %%
df.groupby('Prodotto')['Vendite'].sum()
# Out:
# Prodotto
# A    220
# B    280
# Name: Vendite, dtype: int64

# %% [markdown]
# # Pandas `melt()`
#
# Il metodo melt() di pandas serve per trasformare un DataFrame "largo" in uno "lungo" — cioè passare da colonne multiple a due colonne: una con i nomi delle variabili e una con i valori.

# %%
df_short = pd.DataFrame({
    'Data': ['2024-01', '2024-02'],
    'A': [100, 150],
    'B': [120, 130]
})
df_short
# Out:
#       Data    A    B
# 0  2024-01  100  120
# 1  2024-02  150  130

# %%
df_short.melt(id_vars = 'Data', var_name = 'Prodotto', value_name = 'Vendite')
# Out:
#       Data Prodotto  Vendite
# 0  2024-01        A      100
# 1  2024-02        A      150
# 2  2024-01        B      120
# 3  2024-02        B      130

# %% [markdown]
# ## Esempio uso pivot
#
# Contiamo quanti lavori per ogni tipo ci sono

# %%
df.pivot_table(index='Job_Title', aggfunc='size').sort_values(ascending=False)
# Out:
# Job_Title
# Software Engineer                                                     311
# Product Manager  Social app startup                                   282
# Associate Product Manager  Social app startup                         277
# 2025 Virtual Summer Intern Program - Product Analyst Intern (Xome)    267
# Real-Time Software Engineer                                           266
#                                                                      ...
# Information Systems Security Engineer, Senior                           1
# Information Systems Security Engineering (ISSE)                         1
# Information Systems Security Officer/ Engineer                          1
# Information Technology - Senior Business Analyst IT                     1
# ☁ Cloud HPC Engineer ☁                                                  1
# Length: 4848, dtype: int64

# %%
df.groupby('Job_Title').size().sort_values(ascending=False)
# Out:
# Job_Title
# Software Engineer                                                     311
# Product Manager  Social app startup                                   282
# Associate Product Manager  Social app startup                         277
# 2025 Virtual Summer Intern Program - Product Analyst Intern (Xome)    267
# Real-Time Software Engineer                                           266
#                                                                      ...
# Information Systems Security Engineer, Senior                           1
# Information Systems Security Engineering (ISSE)                         1
# Information Systems Security Officer/ Engineer                          1
# Information Technology - Senior Business Analyst IT                     1
# ☁ Cloud HPC Engineer ☁                                                  1
# Length: 4848, dtype: int64
